# %%
import pandas as pd

# %%
df=pd.read_excel("C:/Users/c_care/Desktop/IPL Matches 2008-2020.xlsx","IPL Matches 2008-2020")
df
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
s=df['result']
s
# Out:
# 0         runs
# 1         runs
# 2      wickets
# 3      wickets
# 4      wickets
#         ...
# 811        tie
# 812       runs
# 813    wickets
# 814       runs
# 815    wickets
# Name: result, Length: 816, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df['result']=pd.to_numeric(df['result'],errors='coerce')

# %%
df
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           0 non-null      float64
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df.head(4)
# Out:
#        id        city       date player_of_match  \
# 0  335982   Bangalore 2008-04-18     BB McCullum
# 1  335983  Chandigarh 2008-04-19      MEK Hussey
# 2  335984       Delhi 2008-04-19     MF Maharoof
# 3  335985      Mumbai 2008-04-20      MV Boucher
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# 3               Mumbai Indians  Royal Challengers Bangalore
#
#                    toss_winner toss_decision                       winner  \
# ...

# %%
df['id']
# Out:
# 0       335982
# 1       335983
# 2       335984
# 3       335985
# 4       335986
#         ...
# 811    1216547
# 812    1237177
# 813    1237178
# 814    1237180
# 815    1237181
# Name: id, Length: 816, dtype: int64

# %%
df["id"].mean()
# Out:
# 756349.5539215687

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.mean(df['id'])
# Out:
# 756349.5539215687

# %%
sns.histplot(x="id",data=df)
plt.show()

# %%
df.corr()
# Out:
#                      id  neutral_venue  result  result_margin
# id             1.000000      -0.292042     NaN      -0.010501
# neutral_venue -0.292042       1.000000     NaN      -0.006445
# result              NaN            NaN     NaN            NaN
# result_margin -0.010501      -0.006445     NaN       1.000000

# %%
df
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
s=df['result']
s2=list(s)
s2
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.plot.bar
# Out:
# <bound method PlotAccessor.bar of <pandas.plotting._core.PlotAccessor object at 0x00000142DE058A00>>

# %%
t=df['city']

# %%
t2=list(t)
t2
# Out:
# ['Bangalore',
#  'Chandigarh',
#  'Delhi',
#  'Mumbai',
#  'Kolkata',
#  'Jaipur',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chandigarh',
#  'Bangalore',
#  'Chennai',
#  'Mumbai',
#  'Chandigarh',
#  'Bangalore',
#  'Kolkata',
#  'Delhi',
#  'Hyderabad',
#  'Jaipur',
#  'Chennai',
#  'Hyderabad',
#  'Chandigarh',
#  'Mumbai',
#  'Jaipur',
#  'Bangalore',
#  'Chennai',
#  'Mumbai',
#  'Delhi',
#  'Kolkata',
#  'Jaipur',
#  'Bangalore',
#  'Chennai',
#  'Hyderabad',
#  'Jaipur',
#  'Chandigarh',
#  'Kolkata',
#  'Mumbai',
#  'Chandigarh',
#  'Delhi',
#  'Mumbai',
#  'Delhi',
#  'Jaipur',
#  'Hyderabad',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Mumbai',
#  'Chennai',
#  'Chandigarh',
#  'Delhi',
#  'Chennai',
#  'Bangalore',
#  'Kolkata',
#  'Jaipur',
#  'Hyderabad',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Cape Town',
#  'Cape Town',
#  'Cape Town',
#  'Cape Town',
#  'Port Elizabeth',
#  'Durban',
#  'Cape Town',
#  'Durban',
#  'Cape Town',
#  'Durban',
# ...

# %%
import pandas as pd

# %%
p=pd.Series(s2,index=t2)
p
# Out:
# Bangalore    NaN
# Chandigarh   NaN
# Delhi        NaN
# Mumbai       NaN
# Kolkata      NaN
#               ..
# Dubai        NaN
# Dubai        NaN
# Abu Dhabi    NaN
# Abu Dhabi    NaN
# Dubai        NaN
# Length: 816, dtype: float64

# %%
p.plot()
# Out:
# <AxesSubplot:>
